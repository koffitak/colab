# %%
# importer les bibliothèques
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Lire la base de donnée
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a52607a-5224-4d6f-92e7-ef21b76b76fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a52607a-5224-4d6f-92e7-ef21b76b76fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.csv to tips.csv

# %%
tips=pd.read_csv(io.BytesIO(uploaded['tips.csv']))

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
female_data=tips[tips.sex=="Female"]
female_data.head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
tips.loc[4,:]
# Out:
# total_bill     24.59
# tip             3.61
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 4, dtype: object

# %%
tips.loc[2:30,'tip']
# Out:
# 2     3.50
# 3     3.31
# 4     3.61
# 5     4.71
# 6     2.00
# 7     3.12
# 8     1.96
# 9     3.23
# 10    1.71
# 11    5.00
# 12    1.57
# 13    3.00
# 14    3.02
# 15    3.92
# 16    1.67
# 17    3.71
# 18    3.50
# 19    3.35
# 20    4.08
# 21    2.75
# 22    2.23
# 23    7.58
# 24    3.18
# 25    2.34
# 26    2.00
# 27    2.00
# 28    4.30
# 29    3.00
# 30    1.45
# Name: tip, dtype: float64

# %%
tips.loc[2:30,['tip','total_bill']]
# Out:
#      tip  total_bill
# 2   3.50       21.01
# 3   3.31       23.68
# 4   3.61       24.59
# 5   4.71       25.29
# 6   2.00        8.77
# 7   3.12       26.88
# 8   1.96       15.04
# 9   3.23       14.78
# 10  1.71       10.27
# 11  5.00       35.26
# 12  1.57       15.42
# 13  3.00       18.43
# 14  3.02       14.83
# 15  3.92       21.58
# 16  1.67       10.33
# 17  3.71       16.29
# 18  3.50       16.97
# 19  3.35       20.65
# 20  4.08       17.92
# 21  2.75       20.29
# 22  2.23       15.77
# 23  7.58       39.42
# 24  3.18       19.82
# 25  2.34       17.81
# 26  2.00       13.37
# 27  2.00       12.69
# 28  4.30       21.70
# 29  3.00       19.65
# 30  1.45        9.55

# %%
tips.iloc[2:30,[1,0]]
# Out:
#      tip  total_bill
# 2   3.50       21.01
# 3   3.31       23.68
# 4   3.61       24.59
# 5   4.71       25.29
# 6   2.00        8.77
# 7   3.12       26.88
# 8   1.96       15.04
# 9   3.23       14.78
# 10  1.71       10.27
# 11  5.00       35.26
# 12  1.57       15.42
# 13  3.00       18.43
# 14  3.02       14.83
# 15  3.92       21.58
# 16  1.67       10.33
# 17  3.71       16.29
# 18  3.50       16.97
# 19  3.35       20.65
# 20  4.08       17.92
# 21  2.75       20.29
# 22  2.23       15.77
# 23  7.58       39.42
# 24  3.18       19.82
# 25  2.34       17.81
# 26  2.00       13.37
# 27  2.00       12.69
# 28  4.30       21.70
# 29  3.00       19.65

# %%
plt.scatter(tips.total_bill, tips.tip)
plt.xlabel('total bill')
plt.ylabel('tips')
plt.show()
