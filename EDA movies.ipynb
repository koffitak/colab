# %%
#importer les packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#ouvrir la base de donnée (dataset)
df=pd.read_csv('/content/drive/MyDrive/Kaggle/tmdb_movies_data/tmdb_movies_data.csv')

# %%
df.head(10)
# Out:
#        id    imdb_id  popularity  ...  release_year    budget_adj   revenue_adj
# 0  135397  tt0369610   32.985763  ...          2015  1.379999e+08  1.392446e+09
# 1   76341  tt1392190   28.419936  ...          2015  1.379999e+08  3.481613e+08
# 2  262500  tt2908446   13.112507  ...          2015  1.012000e+08  2.716190e+08
# 3  140607  tt2488496   11.173104  ...          2015  1.839999e+08  1.902723e+09
# 4  168259  tt2820852    9.335014  ...          2015  1.747999e+08  1.385749e+09
# 5  281957  tt1663202    9.110700  ...          2015  1.241999e+08  4.903142e+08
# 6   87101  tt1340138    8.654359  ...          2015  1.425999e+08  4.053551e+08
# 7  286217  tt3659388    7.667400  ...          2015  9.935996e+07  5.477497e+08
# 8  211672  tt2293640    7.404165  ...          2015  6.807997e+07  1.064192e+09
# 9  150540  tt2096673    6.326804  ...          2015  1.609999e+08  7.854116e+08
#
# [10 rows x 21 columns]

# %%
df.tail()
# Out:
#           id    imdb_id  popularity  ...  release_year   budget_adj revenue_adj
# 10861     21  tt0060371    0.080598  ...          1966       0.0000         0.0
# 10862  20379  tt0060472    0.065543  ...          1966       0.0000         0.0
# 10863  39768  tt0060161    0.065141  ...          1966       0.0000         0.0
# 10864  21449  tt0061177    0.064317  ...          1966       0.0000         0.0
# 10865  22293  tt0060666    0.035919  ...          1966  127642.2792         0.0
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#                   id    popularity  ...    budget_adj   revenue_adj
# count   10866.000000  10866.000000  ...  1.086600e+04  1.086600e+04
# mean    66064.177434      0.646441  ...  1.755104e+07  5.136436e+07
# std     92130.136561      1.000185  ...  3.430616e+07  1.446325e+08
# min         5.000000      0.000065  ...  0.000000e+00  0.000000e+00
# 25%     10596.250000      0.207583  ...  0.000000e+00  0.000000e+00
# 50%     20669.000000      0.383856  ...  0.000000e+00  0.000000e+00
# 75%     75610.000000      0.713817  ...  2.085325e+07  3.369710e+07
# max    417859.000000     32.985763  ...  4.250000e+08  2.827124e+09
#
# [8 rows x 10 columns]

# %% [markdown]
# Nettoyage des données (Data cleaning)

# %%
# Supprimer les lignes répétées
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Découverte des valeurs manquantes
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7929
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
deleted_columns = ['id', 'imdb_id', 'budget', 'revenue', 
       'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
       'runtime', 'production_companies', 'release_date']

df.drop(deleted_columns, axis=1, inplace=True)
df.head()
# Out:
#    popularity                original_title  ...   budget_adj   revenue_adj
# 0   32.985763                Jurassic World  ...  137999939.3  1.392446e+09
# 1   28.419936            Mad Max: Fury Road  ...  137999939.3  3.481613e+08
# 2   13.112507                     Insurgent  ...  101199955.5  2.716190e+08
# 3   11.173104  Star Wars: The Force Awakens  ...  183999919.0  1.902723e+09
# 4    9.335014                     Furious 7  ...  174799923.1  1.385749e+09
#
# [5 rows x 8 columns]

# %%
# Découverte des valeurs manquantes
df.isnull().sum()
# Out:
# popularity         0
# original_title     0
# genres            23
# vote_count         0
# vote_average       0
# release_year       0
# budget_adj         0
# revenue_adj        0
# dtype: int64

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (10842, 8)

# %%
# Découverte des valeurs manquantes
df.isnull().sum()
# Out:
# popularity        0
# original_title    0
# genres            0
# vote_count        0
# vote_average      0
# release_year      0
# budget_adj        0
# revenue_adj       0
# dtype: int64

# %%
# Recodage de la colonnes "genres"
list_genre = []
for i in df['genres']:
  i=i.split('|')
  list_genre.append(i[0])
df['genres_adj']=list_genre

# %% [markdown]
# Analyse exploratoire

# %%
# Analyse univariée
df['revenue_adj'].mean()
# Out:
# 51477974.92242094

# %%
df['budget_adj'].mean()
# Out:
# 17587121.438276574

# %%
df['vote_average'].mean()
# Out:
# 5.974063825862405

# %%
df['vote_average'].unique()
# Out:
# array([6.5, 7.1, 6.3, 7.5, 7.3, 7.2, 5.8, 7.6, 8. , 6.2, 5.2, 7.4, 6.1,
#        7. , 6.8, 5.3, 7.8, 6.4, 6.6, 7.7, 5.6, 6.9, 5.9, 6.7, 5.5, 5. ,
#        4.4, 5.4, 5.1, 4.8, 5.7, 4.1, 3.9, 4.5, 6. , 4.2, 3.6, 4.3, 4.9,
#        4.7, 4. , 3.5, 3.8, 3.3, 3.7, 4.6, 7.9, 8.2, 2.6, 3.1, 8.9, 3.2,
#        2.4, 8.4, 3. , 2.8, 3.4, 8.8, 8.1, 8.3, 2.7, 2.5, 2.1, 8.6, 2.9,
#        8.5, 9.2, 2.2, 2. , 8.7, 2.3, 1.5])

# %%
df['genres_adj'].unique()
# Out:
# array(['Action', 'Adventure', 'Western', 'Science Fiction', 'Drama',
#        'Family', 'Comedy', 'Crime', 'Romance', 'War', 'Mystery',
#        'Thriller', 'Fantasy', 'History', 'Animation', 'Horror', 'Music',
#        'Documentary', 'TV Movie', 'Foreign'], dtype=object)

# %%
df['genres_adj'].value_counts()
# Out:
# Drama              2453
# Comedy             2319
# Action             1590
# Horror              915
# Adventure           586
# Thriller            491
# Documentary         432
# Animation           403
# Crime               380
# Fantasy             272
# Science Fiction     214
# Romance             186
# Family              144
# Mystery             125
# Music               100
# TV Movie             78
# War                  59
# History              44
# Western              42
# Foreign               9
# Name: genres_adj, dtype: int64

# %%
df['vote_average'].plot(kind='hist')

# %%
df['budget_adj'].plot(kind='hist')

# %%
df['revenue_adj'].plot(kind='hist')

# %%
# Analyse bivariée - la matrice de correlation
corr=df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220,20, as_cmap=True))

# %%
df.plot(kind='scatter', x='budget_adj' ,y='revenue_adj')

# %%
df.plot(kind='scatter', x='vote_count' ,y='revenue_adj')

# %%
df.plot(kind='scatter', x='vote_average' ,y='revenue_adj')

# %% [markdown]
# Q1: Quel est le genre de film qui a un très bon revenu ?

# %%
df.groupby(['genres_adj'])['revenue_adj'].mean()
# Out:
# genres_adj
# Action             7.401006e+07
# Adventure          1.665356e+08
# Animation          7.671443e+07
# Comedy             3.837766e+07
# Crime              4.686688e+07
# Documentary        2.150125e+06
# Drama              3.578622e+07
# Family             7.724863e+07
# Fantasy            8.283760e+07
# Foreign            0.000000e+00
# History            6.536195e+07
# Horror             2.417979e+07
# Music              3.807907e+07
# Mystery            3.002289e+07
# Romance            4.721514e+07
# Science Fiction    9.951810e+07
# TV Movie           7.485782e+05
# Thriller           3.096924e+07
# War                4.874310e+07
# Western            4.730739e+07
# Name: revenue_adj, dtype: float64

# %%
df_genre_rev = df.groupby(['genres_adj'])['revenue_adj'].mean()

# %%
df_genre_rev.plot(kind='bar')

# %%
df_genre_budget = df.groupby(['genres_adj'])['budget_adj'].mean()
df_genre_budget.plot(kind='bar')

# %% [markdown]
# Q2: Les caractéristiques des films avec un très bon revenu ?

# %%
df.plot(kind='scatter', x='vote_average' ,y='revenue_adj')

# %%
df.plot(kind='scatter', x='budget_adj' ,y='revenue_adj')
