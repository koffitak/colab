# %%
#Installation package kaggle
! pip install -q kaggle

# %%
# Créer un dossier kaggle
! mkdir ~/.kaggle/

# %%
# Copier kaggle.json dans le dossier kaggle
! cp '/content/drive/MyDrive/Kaggle/kaggle.json' ~/.kaggle/

# %%
# Donner les droits à kaggle.json
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                              title                                               size  lastUpdated          downloadCount
# ---------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------
# yasserh/wine-quality-dataset                                     Wine Quality Dataset                                21KB  2022-01-15 19:15:11           7718
# mkoklu42/pistachio-dataset                                       Pistachio Dataset                                    2MB  2022-02-11 21:06:50             75
# prasertk/netflix-subscription-price-in-different-countries       Netflix subscription fee in different countries      3KB  2022-01-15 07:06:09           5915
# majyhain/height-of-male-and-female-by-country-2022               Height of Male and Female by Country 2022            4KB  2022-02-02 00:40:19           3100
# ashishjangra27/ted-talks                                         TED Talks                                          298KB  2022-02-23 15:16:08            634
# jainilcoder/netflix-stock-price-prediction                       Netflix Stock Price Prediction                      21KB  2022-02-05 05:06:10           1154
# shivavashishtha/shark-tank-india-dataset                         Shark Tank India Dataset                             4KB  2022-02-24 12:57:31            395
# mkoklu42/pumpkin-seeds-dataset                                   Pumpkin Seeds Dataset                              393KB  2022-02-08 15:54:27            356
# sanjeetsinghnaik/top-1000-highest-grossing-movies                Top 1000 Highest Grossing Movies                   106KB  2022-01-15 16:26:14           3912
# mkoklu42/acoustic-extinguisher-fire-dataset                      Acoustic Extinguisher Fire Dataset                 620KB  2022-02-09 17:59:52             47
# georgesaavedra/covid19-dataset                                   COVID-19 dataset                                     9MB  2022-02-25 19:13:10           3134
# soumyadiptadas/products-sales-timeseries-data                    Products sales time-series data                      1KB  2022-02-24 08:21:51            335
# prasertk/michelinstar-restaurants                                Michelin "star" restaurants                        364KB  2022-02-23 00:28:16            346
# soumyadiptadas/students-math-score-for-different-teaching-style  Student's math score for different teaching style    2KB  2022-02-23 12:36:06            478
# robikscube/ubiquant-parquet                                      Ubiquant Competition Data in Parquet Format         13GB  2022-01-19 14:18:59           2175
# mkoklu42/dry-bean-dataset                                        Dry Bean Dataset                                     2MB  2022-02-08 12:36:26             39
# mkoklu42/rice-msc-dataset                                        Rice MSC Dataset                                   102MB  2022-02-08 12:27:51             41
# prokaggler/global-mobility-data-during-covid-19                  Global Mobility Data during Covid 19                67MB  2022-02-23 13:37:41            204
# datasnaek/youtube-new                                            Trending YouTube Video Statistics                  201MB  2019-06-03 00:56:47         167037
# zynicide/wine-reviews                                            Wine Reviews                                        51MB  2017-11-27 17:08:04         155155

# %%
! kaggle datasets download -d
# Out:
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [00:19<00:00, 115MB/s]
# 100% 2.29G/2.29G [00:19<00:00, 128MB/s]

# %%
! unzip /content/archive.zip -d tips
# Out:
# Archive:  /content/archive.zip
#   inflating: tips/tips.csv
